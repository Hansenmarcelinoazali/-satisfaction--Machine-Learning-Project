# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # problem

# %% [raw]
# 1. mencari tahu seberapa banyak pekerja yang puas(satified) dengan pekerjaan mereka
# 2. mencari tahu berapa umur pekerja yang paling muda dan yang paling tua dalam perusahaan untuk
# mempertimbangkan pencarian karyawan baru jika pekerja yang tua sudah pensiun
# 3. mencari tahu gaji tertinggi, terendah dan gaji rata-rata para karyawan
# 4. mencari tahu latar belakang pendidikan karyawan
# 5.

# %%
df = pd.read_csv(r'C:\data science\folder mentoring\satisfaction.csv')
df
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 0             0    HR8270   28          HR   Suburb        PG
# 1             1  TECH1860   50  Technology   Suburb        PG
# 2             2  TECH6390   43  Technology   Suburb        UG
# 3             3   SAL6191   44       Sales     City        PG
# 4             4    HR6734   33          HR     City        UG
# ..          ...       ...  ...         ...      ...       ...
# 495         495    HR5330   49          HR   Suburb        PG
# 496         496  TECH9010   24  Technology   Suburb        UG
# 497         497   MKT7801   34   Marketing     City        PG
# 498         498  TECH5846   26  Technology     City        UG
# 499         499  TECH7731   26  Technology     City        UG
#
#        recruitment_type  job_level  rating  onsite  awards  certifications  \
# 0              Referral          5       2       0       1               0
# ...

# %%
crosstab_genpub2 = pd.crosstab(df['salary'], df['satisfied']).T
crosstab_genpub2.head(10)
# Out:
# salary     24076  29805  42419  65715  86750
# satisfied
# 0             41     57     41     53     45
# 1             54     53     41     57     58

# %%
crosstab_genpub2.plot(kind='bar')

# %% [raw]
# yang puas kebanyakan memiliki gaji yang lebih tinggi dibandingkan dengan yang tidak puas

# %%
df['age'] = df['age'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        500 non-null    int64
#  1   emp_id            500 non-null    object
#  2   age               500 non-null    int64
#  3   Dept              500 non-null    object
#  4   location          500 non-null    object
#  5   education         500 non-null    object
#  6   recruitment_type  500 non-null    object
#  7   job_level         500 non-null    int64
#  8   rating            500 non-null    int64
#  9   onsite            500 non-null    int64
#  10  awards            500 non-null    int64
#  11  certifications    500 non-null    int64
#  12  salary            500 non-null    int64
#  13  satisfied         500 non-null    int64
# dtypes: int64(9), object(5)
# memory usage: 54.8+ KB

# %%
df.shape
#terdapat 500 baris data dan 14 kolom data di dalam data frame.
# Out:
# (500, 14)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# emp_id              0
# age                 0
# Dept                0
# location            0
# education           0
# recruitment_type    0
# job_level           0
# rating              0
# onsite              0
# awards              0
# certifications      0
# salary              0
# satisfied           0
# dtype: int64

# %%
df['education'].value_counts()
# Out:
# PG    254
# UG    246
# Name: education, dtype: int64

# %% [markdown]
# tidak ada missing value di dalam data set tersebut

# %% [markdown]
# # Cleaning data

# %%
df.drop('onsite', axis = 'columns', inplace= True)

# %%
df
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 0             0    HR8270   28          HR   Suburb        PG
# 1             1  TECH1860   50  Technology   Suburb        PG
# 2             2  TECH6390   43  Technology   Suburb        UG
# 3             3   SAL6191   44       Sales     City        PG
# 4             4    HR6734   33          HR     City        UG
# ..          ...       ...  ...         ...      ...       ...
# 495         495    HR5330   49          HR   Suburb        PG
# 496         496  TECH9010   24  Technology   Suburb        UG
# 497         497   MKT7801   34   Marketing     City        PG
# 498         498  TECH5846   26  Technology     City        UG
# 499         499  TECH7731   26  Technology     City        UG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 0              Referral          5       2       1               0   86750
# ...

# %% [raw]
# data yang di drop adalah data dari columns = onsite
# karena untuk data yang diperlukan tidak menggunakan onsite dan tidak menampilakn identitas atau keterangan penting apapun di dalam kasus

# %%
#menampilkan 5 data teratas sesudah di drop column onsite
df.head()
# Out:
#    Unnamed: 0    emp_id  age        Dept location education  \
# 0           0    HR8270   28          HR   Suburb        PG
# 1           1  TECH1860   50  Technology   Suburb        PG
# 2           2  TECH6390   43  Technology   Suburb        UG
# 3           3   SAL6191   44       Sales     City        PG
# 4           4    HR6734   33          HR     City        UG
#
#      recruitment_type  job_level  rating  awards  certifications  salary  \
# 0            Referral          5       2       1               0   86750
# 1             Walk-in          3       5       2               1   42419
# 2            Referral          4       1       2               0   65715
# 3           On-Campus          2       3       0               0   29805
# 4  Recruitment Agency          2       1       5               0   29805
#
#    satisfied
# 0          1
# 1          0
# 2          0
# 3          1
# 4          1

# %%
df.describe()
# Out:
#        Unnamed: 0         age   job_level      rating      awards  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   249.500000   38.610000    3.032000    3.072000    4.538000
# std    144.481833    9.438648    1.423738    1.425089    2.853215
# min      0.000000   23.000000    1.000000    1.000000    0.000000
# 25%    124.750000   30.000000    2.000000    2.000000    2.000000
# 50%    249.500000   39.000000    3.000000    3.000000    5.000000
# 75%    374.250000   47.000000    4.000000    4.000000    7.000000
# max    499.000000   54.000000    5.000000    5.000000    9.000000
#
#        certifications        salary   satisfied
# count      500.000000    500.000000  500.000000
# mean         0.496000  50416.056000    0.526000
# std          0.500485  23671.392661    0.499824
# min          0.000000  24076.000000    0.000000
# 25%          0.000000  29805.000000    0.000000
# 50%          0.000000  42419.000000    1.000000
# ...

# %% [markdown]
# # jumlah dari karyawan yang puas

# %%
df['satisfied'].value_counts()
# Out:
# 1    263
# 0    237
# Name: satisfied, dtype: int64

# %%
#jumlah dari karyawan yang puas dengan pekerjaan merek adalah sebanyak 263 orang  dan 237 tidak puas dengan pekerjaan mereka

# %%
plt.figure(figsize=(5,5))
sns.countplot(x = df['satisfied'])

# %% [markdown]
# # gaji tertinggi dan terendah karyawan

# %%
df_gaji_max=df.describe().loc['max','salary']
#gaji tertinggi yang di dapatkan oleh karyawan dan sesuai dengan dari df.head()

# %%
df_gaji_max
# Out:
# 86750.0

# %%
df_gaji_maxi = df.loc[df['salary']==df_gaji_max]

# %%
df_gaji_maxi
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 0             0    HR8270   28          HR   Suburb        PG
# 6             6   PUR1466   26  Purchasing   Suburb        UG
# 14           14   PUR6311   52  Purchasing     City        PG
# 15           15   PUR6051   50  Purchasing     City        UG
# 19           19   SAL4385   25       Sales     City        UG
# ..          ...       ...  ...         ...      ...       ...
# 478         478  TECH8266   46  Technology     City        PG
# 482         482   MKT8651   28   Marketing   Suburb        PG
# 485         485   PUR2062   47  Purchasing     City        UG
# 487         487  TECH8860   51  Technology   Suburb        UG
# 493         493   MKT6334   41   Marketing     City        UG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 0              Referral          5       2       1               0   86750
# ...

# %%
df_gaji_maxi['job_level'].value_counts()
# Out:
# 5    103
# Name: job_level, dtype: int64

# %%
df_gaji_maxi['education'].value_counts()
# Out:
# PG    53
# UG    50
# Name: education, dtype: int64

# %%
df['education'].value_counts()
# Out:
# PG    254
# UG    246
# Name: education, dtype: int64

# %% [markdown]
# karyawan dengan gaji terendah rendah

# %%
df_gaji_min=df.describe().loc['min','salary']

# %%
df_gaji_min
# Out:
# 24076.0

# %%
df_gaji_mini = df.loc[df['salary']==df_gaji_min]

# %%
df_gaji_mini
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 7             7  TECH5426   25  Technology     City        UG
# 16           16   MKT7420   34   Marketing     City        PG
# 18           18    HR5555   54          HR   Suburb        PG
# 30           30  TECH2899   54  Technology     City        UG
# 32           32   MKT2267   49   Marketing   Suburb        PG
# ..          ...       ...  ...         ...      ...       ...
# 463         463   SAL5492   34       Sales     City        UG
# 468         468   SAL9082   39       Sales     City        PG
# 469         469  TECH5171   48  Technology     City        PG
# 476         476   PUR9335   39  Purchasing   Suburb        UG
# 497         497   MKT7801   34   Marketing     City        PG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 7    Recruitment Agency          1       1       4               0   24076
# ...

# %%
df_gaji_mini['education'].value_counts()
# Out:
# PG    51
# UG    44
# Name: education, dtype: int64

# %% [markdown]
# # perbandingan jenis recruitment pada orang yang memiliki gaji tertinggi dan keseluruhan pada recruitment

# %%
df_gaji_maxi['recruitment_type'].value_counts()
# Out:
# Walk-in               32
# On-Campus             28
# Referral              24
# Recruitment Agency    19
# Name: recruitment_type, dtype: int64

# %%
df['recruitment_type'].value_counts()
# Out:
# On-Campus             133
# Referral              131
# Walk-in               128
# Recruitment Agency    108
# Name: recruitment_type, dtype: int64

# %% [raw]
# untuk orang dengan gaji yang tertinggi rata-rata di dominasi dengan recruitment walk-in

# %% [markdown]
# # umur karyawan

# %%
df_umur_tinggi = df.describe().loc['max','age']

# %%
df_umur_tinggi
# Out:
# 54.0

# %%
df_umur_tinggi = df.loc[df['age']==df_umur_tinggi]

# %%
df_umur_tinggi
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 18           18    HR5555   54          HR   Suburb        PG
# 30           30  TECH2899   54  Technology     City        UG
# 68           68  TECH9529   54  Technology     City        UG
# 97           97   PUR9996   54  Purchasing     City        UG
# 132         132   PUR6915   54  Purchasing   Suburb        UG
# 151         151   PUR2495   54  Purchasing   Suburb        PG
# 201         201   PUR9680   54  Purchasing   Suburb        PG
# 233         233  TECH3557   54  Technology   Suburb        UG
# 248         248    HR7015   54          HR     City        UG
# 277         277    HR4420   54          HR     City        PG
# 293         293    HR7709   54          HR   Suburb        PG
# 302         302    HR4009   54          HR   Suburb        UG
# 339         339   MKT4854   54   Marketing     City        UG
# 353         353   SAL8987   54       Sales   Suburb        PG
# ...

# %%
df_umur_tinggi = df.loc[df['age']==df_umur_tinggi]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-273-4d29a759e9e5> in <module>
# ----> 1 df_umur_tinggi = df.loc[df['age']==df_umur_tinggi]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1950
#    1951                 if hasattr(key, "ndim") and key.ndim > 1:
# -> 1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
#    1954                 return self._getitem_iterable(key, axis=axis)
#
# ValueError: Cannot index with multidimensional key

# %%
df_umur_rendah = df.describe().loc['min','age']

# %%
df_umur_rendah
# Out:
# 23.0

# %%
df_umur_tinggi['job_level'].value_counts()
# Out:
# 5    5
# 1    5
# 4    4
# 3    3
# 2    2
# Name: job_level, dtype: int64

# %%
df_umur_tinggi.head()
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 18           18    HR5555   54          HR   Suburb        PG
# 30           30  TECH2899   54  Technology     City        UG
# 68           68  TECH9529   54  Technology     City        UG
# 97           97   PUR9996   54  Purchasing     City        UG
# 132         132   PUR6915   54  Purchasing   Suburb        UG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 18            On-Campus          1       5       4               0   24076
# 30            On-Campus          1       5       2               1   24076
# 68              Walk-in          3       4       5               1   42419
# 97              Walk-in          1       3       7               1   24076
# 132  Recruitment Agency          3       3       0               0   42419
#
#      satisfied
# 18           1
# 30           0
# 68           1
# 97           0
# 132          0

# %%
df_umur_tinggi.sort_values(by=['job_level'])
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 18           18    HR5555   54          HR   Suburb        PG
# 30           30  TECH2899   54  Technology     City        UG
# 424         424   MKT9945   54   Marketing   Suburb        PG
# 97           97   PUR9996   54  Purchasing     City        UG
# 293         293    HR7709   54          HR   Suburb        PG
# 339         339   MKT4854   54   Marketing     City        UG
# 277         277    HR4420   54          HR     City        PG
# 248         248    HR7015   54          HR     City        UG
# 132         132   PUR6915   54  Purchasing   Suburb        UG
# 68           68  TECH9529   54  Technology     City        UG
# 353         353   SAL8987   54       Sales   Suburb        PG
# 366         366   PUR2150   54  Purchasing   Suburb        PG
# 433         433   PUR1825   54  Purchasing   Suburb        PG
# 486         486    HR3156   54          HR     City        PG
# ...

# %%
df_umur_tinggi['satisfied'].value_counts()
# Out:
# 0    11
# 1     8
# Name: satisfied, dtype: int64

# %%
df_umur_tinggi["salary"].mean()
# Out:
# 52834.57894736842

# %%
df_umur_rendah = df.loc[df['age']==df_umur_rendah]

# %%
df_umur_rendah
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 37           37   SAL6393   23       Sales     City        PG
# 48           48   SAL4152   23       Sales   Suburb        UG
# 49           49    HR2585   23          HR     City        UG
# 77           77  TECH3062   23  Technology     City        PG
# 166         166   PUR9164   23  Purchasing     City        PG
# 241         241    HR1956   23          HR     City        PG
# 276         276    HR3327   23          HR   Suburb        PG
# 327         327   PUR7002   23  Purchasing   Suburb        UG
# 331         331   SAL5146   23       Sales     City        PG
# 342         342   MKT6691   23   Marketing   Suburb        PG
# 407         407   SAL2687   23       Sales     City        PG
# 491         491  TECH5729   23  Technology     City        PG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 37   Recruitment Agency          4       2       8               0   65715
# ...

# %%
df_umur_rendah1 = df_umur_rendah['job_level'].value_counts()

# %%
df_umur_rendah1
# Out:
# 5    3
# 4    3
# 1    3
# 3    2
# 2    1
# Name: job_level, dtype: int64

# %%
df_umur_rendah1.plot(kind='bar')

# %%
df_umur_rendah.head()
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 37           37   SAL6393   23       Sales     City        PG
# 48           48   SAL4152   23       Sales   Suburb        UG
# 49           49    HR2585   23          HR     City        UG
# 77           77  TECH3062   23  Technology     City        PG
# 166         166   PUR9164   23  Purchasing     City        PG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 37   Recruitment Agency          4       2       8               0   65715
# 48             Referral          5       5       8               1   86750
# 49             Referral          2       5       8               0   29805
# 77             Referral          4       1       5               0   65715
# 166            Referral          4       3       4               0   65715
#
#      satisfied
# 37           1
# 48           1
# 49           0
# 77           0
# 166          1

# %%
df_umur_rendah['satisfied'].value_counts()
# Out:
# 1    7
# 0    5
# Name: satisfied, dtype: int64

# %%
df_umur_rendah["salary"].mean()
# Out:
# 53688.833333333336

# %%
df_umur_rendah.sort_values(by=['job_level'])
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 276         276    HR3327   23          HR   Suburb        PG
# 342         342   MKT6691   23   Marketing   Suburb        PG
# 407         407   SAL2687   23       Sales     City        PG
# 49           49    HR2585   23          HR     City        UG
# 327         327   PUR7002   23  Purchasing   Suburb        UG
# 491         491  TECH5729   23  Technology     City        PG
# 37           37   SAL6393   23       Sales     City        PG
# 77           77  TECH3062   23  Technology     City        PG
# 166         166   PUR9164   23  Purchasing     City        PG
# 48           48   SAL4152   23       Sales   Suburb        UG
# 241         241    HR1956   23          HR     City        PG
# 331         331   SAL5146   23       Sales     City        PG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 276  Recruitment Agency          1       4       4               1   24076
# ...

# %% [markdown]
# # latar belakang pendidikan

# %%
df_edu = df.sort_values(by=['education'])

# %%
df_edu.sort_values(by=['education'])
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 0             0    HR8270   28          HR   Suburb        PG
# 460         460   SAL9787   53       Sales   Suburb        PG
# 458         458   SAL5968   46       Sales   Suburb        PG
# 457         457    HR3914   40          HR   Suburb        PG
# 74           74    HR9684   46          HR   Suburb        PG
# ..          ...       ...  ...         ...      ...       ...
# 86           86   SAL7736   46       Sales     City        UG
# 85           85  TECH6618   46  Technology   Suburb        UG
# 84           84  TECH6258   52  Technology   Suburb        UG
# 81           81  TECH6463   35  Technology     City        UG
# 499         499  TECH7731   26  Technology     City        UG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 0              Referral          5       2       1               0   86750
# ...

# %%
df_edu['education'].value_counts()
# Out:
# PG    254
# UG    246
# Name: education, dtype: int64

# %%
df_edu.sort_values(by=['job_level'])
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 138         138   PUR8392   31  Purchasing   Suburb        PG
# 69           69    HR1878   27          HR   Suburb        PG
# 352         352  TECH8079   36  Technology   Suburb        PG
# 293         293    HR7709   54          HR   Suburb        PG
# 87           87  TECH1391   49  Technology     City        UG
# ..          ...       ...  ...         ...      ...       ...
# 434         434   SAL8668   40       Sales   Suburb        UG
# 58           58   PUR1161   25  Purchasing     City        UG
# 14           14   PUR6311   52  Purchasing     City        PG
# 241         241    HR1956   23          HR     City        PG
# 0             0    HR8270   28          HR   Suburb        PG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 138            Referral          1       1       3               1   24076
# ...

# %%
df_edu.head(10)
# Out:
#      Unnamed: 0   emp_id  age        Dept location education  \
# 0             0   HR8270   28          HR   Suburb        PG
# 211         211  SAL7616   43       Sales     City        PG
# 209         209  MKT9155   34   Marketing     City        PG
# 208         208   HR2802   37          HR   Suburb        PG
# 206         206  MKT3385   44   Marketing   Suburb        PG
# 205         205  MKT7694   33   Marketing     City        PG
# 388         388   HR6188   46          HR   Suburb        PG
# 214         214  MKT1262   29   Marketing     City        PG
# 203         203  PUR2959   43  Purchasing     City        PG
# 201         201  PUR9680   54  Purchasing   Suburb        PG
#
#        recruitment_type  job_level  rating  awards  certifications  salary  \
# 0              Referral          5       2       1               0   86750
# 211             Walk-in          1       1       9               0   24076
# ...

# %%
#kepuasan kerja berdasarkan latar belakang
crosstab_genpub1 = pd.crosstab(df['education'], df['satisfied']).T
crosstab_genpub1.head(10)
# Out:
# education   PG   UG
# satisfied
# 0          117  120
# 1          137  126

# %%
crosstab_genpub1.plot(kind='bar')

# %% [raw]
# untuk kepuasan kerja dengan visualisasi menunjukan bahwa
# lulusan UG jauh lebih banyak tidak puas dengan pekerjaan mereka dibandingkan dengan PG walapun tidak signifikan
# dan untuk yang puas dengan pekerjaan mereka kebanyak PG jauh lebih puas walapun juga tidak signifikan

# %%
#analisis job_level pada pendidikan karyawan
crosstab_genpub = pd.crosstab(df['education'], df['job_level']).T
crosstab_genpub.head(10)
# Out:
# education  PG  UG
# job_level
# 1          51  44
# 2          55  55
# 3          41  41
# 4          54  56
# 5          53  50

# %%
crosstab_genpub.plot(kind='bar')

# %% [raw]
# analisis dari data visualisasi menunjukan bahwa pekerja dengan level tinggi di dominasi oleh PG dan untuk pekerja dengan level paling rendah di dominasi oleh pg juga

# %% [markdown]
# # jenis perekrutan terhadap kepuasan berkerja

# %%
crosstab_genpub3 = pd.crosstab(df['recruitment_type'], df['satisfied']).T
crosstab_genpub3.head(10)
# Out:
# recruitment_type  On-Campus  Recruitment Agency  Referral  Walk-in
# satisfied
# 0                        61                  49        63       64
# 1                        72                  59        68       64

# %%
crosstab_genpub3.plot(kind='bar')

# %% [markdown]
# perekrutan terhadap gaji#

# %%
crosstab_genpub4 = pd.crosstab(df['recruitment_type'], df['salary']).T
crosstab_genpub4.head(10)
# Out:
# recruitment_type  On-Campus  Recruitment Agency  Referral  Walk-in
# salary
# 24076                    24                  20        31       20
# 29805                    37                  24        27       22
# 42419                    22                  19        22       19
# 65715                    22                  26        27       35
# 86750                    28                  19        24       32

# %%
crosstab_genpub4.plot(kind='bar')

# %% [raw]
# mayoritas pekerja adalah berdasarkan dari latar belakang education PG
#
#
# kesimpulan yang didapatkan adalah bahwa untuk rata-rata gaji karyawan berdasarkan umur adalah di dominasi oleh karyawan dengan umur 23 tahun dengan rata-rata gajinya 53688.833333333336 dan untuk yang sudah berumur 54 tahun 52834.57894736842
#
# dari pekerja yang tua kebanyakan tidak puas dengan pekerjaan mereka sedangkan yang muda kebanyakan puas dengan pekerjaan mereka.
# dari hasil analisis yang mempengaruhi kepuasan mereka dalam bekerja adalah:
# 1. Gaji => karena dari hasil rata-rata gaji mereka adalah yang muda rata-rata memiliki gaji yang lebih tinggi dibandingan dengan mereka yang tua
# 2. Kesulitan pekerjaan/ jabatan => jabatan tinggi atau kesulitan dengan point 5 memang di dominasi oleh orang yang sudah berumur tetapi jika melihat lebih dalam yang di dapatkan adalah orang yang tua juga mendominasi untuk pekerjaan dengan point 1
#
# berdasarkan latar belakang pendidikan karyawan di dominasi oleh PG. untuk jabatan tinggi atau kesulitan lebih tinggipun juga di dominasi oleh PG yang berarti lulusan PG rata-rata mempunyai potensi yang lebih baik dibandingakan dengan UG
# tetapi kepuasan mereka dalam bekerja tidaklah tinggi karena menurut hasil dari 10 lulusan PG yang teratas 6 diantaranya tidaklah puas dengan pekerjaan mereka
# tetapi secara keseluruhan kedua lulusan PG dan UG lebih banyak yang puas dengan pekerjaan yang mereka lakukan walaupun tidak signifikan
#
# analisis crosstab latar belakang pendidikan dengan tingkat kesulitan kerja di dominasi oleh PG dan di ikuti oleh UG. tetapi yang mendominasi tingkat kerja kesulitan 1 adalah PG juga.

# %% [markdown]
# # saran

# %% [raw]
# 1.meerekrut pekerja dari latar belakang PG jauh lebih baik dibandingkan dengan UG karen PG mendominasi kebanyakan dari tingkat2 pekerjaan yang sulit
# 2. lebih memperhatikan kepuasan kerja karyawan karena yang muda atau berumur 23 tahun hampir setengahnya tidak puas dengan pekerjaan mereka.
# 3. lebih memperhatikan jobdesk para pekerjanya karena ketidak puasan mereka bisa di lihat dari gaji karena cukup signifikan bedanya yang tidak puas dan yang puas
# 4. lebih memberikan perhatian pada kemampuan pekerjanya karena latar belakang dan pendidikan mereka berbeda
# 5. Jenis perekrutan dari kampus yang tertinggi
# 6. jenisperekrutan terhadap gaji yang tertinggi juga dari kampus mungkin perusahaan bisa memperbaiki sistem perekrutan karyawan

# %% [markdown]
# # data preprocessing

# %%
df1= pd.read_csv(r'C:\data science\folder mentoring\satisfaction.csv')
df1
# Out:
#      Unnamed: 0    emp_id  age        Dept location education  \
# 0             0    HR8270   28          HR   Suburb        PG
# 1             1  TECH1860   50  Technology   Suburb        PG
# 2             2  TECH6390   43  Technology   Suburb        UG
# 3             3   SAL6191   44       Sales     City        PG
# 4             4    HR6734   33          HR     City        UG
# ..          ...       ...  ...         ...      ...       ...
# 495         495    HR5330   49          HR   Suburb        PG
# 496         496  TECH9010   24  Technology   Suburb        UG
# 497         497   MKT7801   34   Marketing     City        PG
# 498         498  TECH5846   26  Technology     City        UG
# 499         499  TECH7731   26  Technology     City        UG
#
#        recruitment_type  job_level  rating  onsite  awards  certifications  \
# 0              Referral          5       2       0       1               0
# ...

# %%
df1.drop('onsite', axis = 'columns', inplace= True)
#drop kolom insite karena tidak menampilkan data penting karyawan

# %%
df1.describe()
# Out:
#        Unnamed: 0         age   job_level      rating      awards  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   249.500000   38.610000    3.032000    3.072000    4.538000
# std    144.481833    9.438648    1.423738    1.425089    2.853215
# min      0.000000   23.000000    1.000000    1.000000    0.000000
# 25%    124.750000   30.000000    2.000000    2.000000    2.000000
# 50%    249.500000   39.000000    3.000000    3.000000    5.000000
# 75%    374.250000   47.000000    4.000000    4.000000    7.000000
# max    499.000000   54.000000    5.000000    5.000000    9.000000
#
#        certifications        salary   satisfied
# count      500.000000    500.000000  500.000000
# mean         0.496000  50416.056000    0.526000
# std          0.500485  23671.392661    0.499824
# min          0.000000  24076.000000    0.000000
# 25%          0.000000  29805.000000    0.000000
# 50%          0.000000  42419.000000    1.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        500 non-null    int64
#  1   emp_id            500 non-null    object
#  2   age               500 non-null    int64
#  3   Dept              500 non-null    object
#  4   location          500 non-null    object
#  5   education         500 non-null    object
#  6   recruitment_type  500 non-null    object
#  7   job_level         500 non-null    int64
#  8   rating            500 non-null    int64
#  9   awards            500 non-null    int64
#  10  certifications    500 non-null    int64
#  11  salary            500 non-null    int64
#  12  satisfied         500 non-null    int64
# dtypes: int64(8), object(5)
# memory usage: 50.9+ KB

# %%
import re

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Columns: 510 entries, age to emp_id_TECH9958
# dtypes: int32(1), int64(4), object(1), uint8(504)
# memory usage: 267.7+ KB

# %% [markdown]
# # Feature selection

# %%
df_model = df.loc[:,['emp_id','age','Dept','education','job_level','salary','certifications','satisfied']]

# %%
df_model.shape
# Out:
# (500, 8)

# %%
df_model
# Out:
#        emp_id  age        Dept education  job_level  salary  certifications  \
# 0      HR8270   28          HR        PG          5   86750               0
# 1    TECH1860   50  Technology        PG          3   42419               1
# 2    TECH6390   43  Technology        UG          4   65715               0
# 3     SAL6191   44       Sales        PG          2   29805               0
# 4      HR6734   33          HR        UG          2   29805               0
# ..        ...  ...         ...       ...        ...     ...             ...
# 495    HR5330   49          HR        PG          2   29805               0
# 496  TECH9010   24  Technology        UG          2   29805               0
# 497   MKT7801   34   Marketing        PG          1   24076               0
# 498  TECH5846   26  Technology        UG          2   29805               1
# 499  TECH7731   26  Technology        UG          3   42419               0
#
#      satisfied
# 0            1
# 1            0
# ...

# %% [markdown]
# # Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df_model = pd.get_dummies(df_model, columns=['Dept'])

# %%
df_model = pd.get_dummies(df_model, columns=['emp_id'])

# %% [markdown]
# # menghilangkan Outlier dari target

# %%
q3 = df1.salary.quantile(0.75)
q1 = df1.salary.quantile(0.25)
uw = q3 + (1.5*(q3-q1))
lw = q1 - (1.5*(q3-q1))

# %%
df1 = df1[df1.salary.between(lw,uw)]

# %%
df_model.shape
# Out:
# (500, 506)

# %%
q3 = df1.salary.quantile(0.75)
q1 = q3 = df1.salary.quantile(0.25)
lw = q1 - (1.5*(q3-q1))

# %%
df1 = df1[df1.salary>lw]

# %%
df1.shape
# Out:
# (213, 307)

# %% [markdown]
# # machine Learning (splitting data)

# %%
from sklearn.model_selection import train_test_split

# %%
df.salary.quantile(0.75) - df.salary.quantile(0.25)
# Out:
# 35910.0

# %%
iql = df.salary.quantile(0.75) - df.salary.quantile(0.25)
outlier = df.salary.quantile(0.75) + (1.5*iql)
outlier
# Out:
# 119580.0

# %%
dfx = df1[df1.salary <= outlier]

# %%
x = df1.drop(columns='salary')
y = df1.salary

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,train_size = 0.8, random_state=22)

# %%
xtrain.head()
# Out:
#      Unnamed: 0  age        Dept location education    recruitment_type  \
# 170         170   51  Purchasing     City        UG           On-Campus
# 344         344   25          HR     City        PG           On-Campus
# 60           60   37   Marketing   Suburb        PG  Recruitment Agency
# 25           25   53       Sales   Suburb        PG  Recruitment Agency
# 214         214   29   Marketing     City        PG             Walk-in
#
#      job_level  rating  awards  certifications  ...  emp_id_TECH8253  \
# 170          5       2       0               1  ...                0
# 344          4       4       1               0  ...                0
# 60           5       4       7               0  ...                0
# 25           4       5       8               1  ...                0
# 214          4       2       8               1  ...                0
#
#      emp_id_TECH8266  emp_id_TECH8526  emp_id_TECH8543  emp_id_TECH8734  \
# ...

# %%
xtest.head()
# Out:
#      Unnamed: 0  age        Dept location education    recruitment_type  \
# 382         382   28  Purchasing     City        PG            Referral
# 100         100   41       Sales     City        PG  Recruitment Agency
# 278         278   30  Purchasing     City        UG            Referral
# 478         478   46  Technology     City        PG           On-Campus
# 171         171   25  Purchasing   Suburb        PG             Walk-in
#
#      job_level  rating  awards  certifications  ...  emp_id_TECH8253  \
# 382          4       5       4               0  ...                0
# 100          5       1       9               1  ...                0
# 278          5       5       2               1  ...                0
# 478          5       2       9               0  ...                0
# 171          5       1       0               1  ...                0
#
#      emp_id_TECH8266  emp_id_TECH8526  emp_id_TECH8543  emp_id_TECH8734  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # modeling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
modelLR = LinearRegression()
modelRF = RandomForestRegressor()
modelKN = KNeighborsRegressor()

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
yLR = modelLR.predict(xtest)
yRF = modelRF.predict(xtest)
yKN = modelKN.predict(xtest)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-486-e601bfafa02e> in <module>
# ----> 1 yLR = modelLR.predict(xtest)
#       2 yRF = modelRF.predict(xtest)
#       3 yKN = modelKN.predict(xtest)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     214
#     215     def _decision_function(self, X):
# --> 216         check_is_fitted(self)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %% [raw]
# ^ ini ga tau apa yang salah katanaya ga ke defined

# %%
lrr2 = r2_score(ytest,yLR)
mae = mean_absolute_error(ytest,yLR)
mse = mean_squared_error(ytest,yLR)
rmse = np.sqrt(mse)
LR = pd.DataFrame(data=[lrr2,mae,mse,rmse], index=['R2','MAE','MSE','RMSE'],columns=['Linear Regression'])
LR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-485-8ee13c51df9c> in <module>
# ----> 1 lrr2 = r2_score(ytest,yLR)
#       2 mae = mean_absolute_error(ytest,yLR)
#       3 mse = mean_squared_error(ytest,yLR)
#       4 rmse = np.sqrt(mse)
#       5 LR = pd.DataFrame(data=[lrr2,mae,mse,rmse], index=['R2','MAE','MSE','RMSE'],columns=['Linear Regression'])
#
# NameError: name 'yLR' is not defined

# %%
knr2 = r2_score(ytest,yKN)
mae = mean_absolute_error(ytest,yKN)
mse = mean_squared_error(ytest,yKN)
rmse = np.sqrt(mse)
KN = pd.DataFrame(data=[knr2,mae,mse,rmse], index=['R2','MAE','MSE','RMSE'],columns=['Nearest Neighbour'])
KN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-457-c83df948cb41> in <module>
# ----> 1 knr2 = r2_score(ytest,yKN)
#       2 mae = mean_absolute_error(ytest,yKN)
#       3 mse = mean_squared_error(ytest,yKN)
#       4 rmse = np.sqrt(mse)
#       5 KN = pd.DataFrame(data=[knr2,mae,mse,rmse], index=['R2','MAE','MSE','RMSE'],columns=['Nearest Neighbour'])
#
# NameError: name 'yKN' is not defined

# %%
xtrain.head()
# Out:
#      Unnamed: 0  age        Dept location education    recruitment_type  \
# 170         170   51  Purchasing     City        UG           On-Campus
# 344         344   25          HR     City        PG           On-Campus
# 60           60   37   Marketing   Suburb        PG  Recruitment Agency
# 25           25   53       Sales   Suburb        PG  Recruitment Agency
# 214         214   29   Marketing     City        PG             Walk-in
#
#      job_level  rating  awards  certifications  ...  emp_id_TECH8253  \
# 170          5       2       0               1  ...                0
# 344          4       4       1               0  ...                0
# 60           5       4       7               0  ...                0
# 25           4       5       8               1  ...                0
# 214          4       2       8               1  ...                0
#
#      emp_id_TECH8266  emp_id_TECH8526  emp_id_TECH8543  emp_id_TECH8734  \
# ...

# %%
xtest.head()
# Out:
#      Unnamed: 0  age        Dept location education    recruitment_type  \
# 382         382   28  Purchasing     City        PG            Referral
# 100         100   41       Sales     City        PG  Recruitment Agency
# 278         278   30  Purchasing     City        UG            Referral
# 478         478   46  Technology     City        PG           On-Campus
# 171         171   25  Purchasing   Suburb        PG             Walk-in
#
#      job_level  rating  awards  certifications  ...  emp_id_TECH8253  \
# 382          4       5       4               0  ...                0
# 100          5       1       9               1  ...                0
# 278          5       5       2               1  ...                0
# 478          5       2       9               0  ...                0
# 171          5       1       0               1  ...                0
#
#      emp_id_TECH8266  emp_id_TECH8526  emp_id_TECH8543  emp_id_TECH8734  \
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %%
xtrain.head()
# Out:
#      Unnamed: 0  age        Dept location education    recruitment_type  \
# 170         170   51  Purchasing     City        UG           On-Campus
# 344         344   25          HR     City        PG           On-Campus
# 60           60   37   Marketing   Suburb        PG  Recruitment Agency
# 25           25   53       Sales   Suburb        PG  Recruitment Agency
# 214         214   29   Marketing     City        PG             Walk-in
#
#      job_level  rating  awards  certifications  ...  emp_id_TECH8253  \
# 170          5       2       0               1  ...                0
# 344          4       4       1               0  ...                0
# 60           5       4       7               0  ...                0
# 25           4       5       8               1  ...                0
# 214          4       2       8               1  ...                0
#
#      emp_id_TECH8266  emp_id_TECH8526  emp_id_TECH8543  emp_id_TECH8734  \
# ...

# %%
xtrain.shape
# Out:
# (170, 306)

# %%
xtest.shape
# Out:
# (43, 306)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(xtrain, ytrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-530-4514ea41cabb> in <module>
# ----> 1 model.fit(xtrain, ytrain)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...
